# %%
import numpy as np
import os.path
import pandas
import matplotlib
import scipy.signal

# %matplotlib inline
import matplotlib.pyplot as plt

data_dir = "/Users/humphreys/Documents/IDrive-Sync/Work/Delft/Projects/Notebooks/Analysis/160408_InterferometricStability"

# %% [markdown]
# ## Interferometric trace

# %%
file_name = "IntStab.csv"

filename = os.path.join(data_dir,file_name)

file = open(filename)
for x in range(9):
        line = file.readline()
        if "HResolution" in line:
            TimeRes = float(line[-18:-1])
file.close()

subdiv = 10
data = pandas.read_csv(os.path.join(data_dir,filename),header=None,skiprows = 15)
data = data.drop([0,2],1)
data = data.rolling(window = 100).mean()
data = data.as_matrix()[100:-100:subdiv]

resn = TimeRes*subdiv
t = resn*np.arange(len(data))


NormMax = np.amax(data); NormMin = np.amin(data)
data = (np.array(data)-(NormMax+NormMin)/2)*(2./(NormMax-NormMin))

# %%
fig = plt.figure(figsize=(12, 3))

ax = plt.subplot(1,3,1)
plt.plot(t,data)
plt.xlabel('time (s)')
plt.ylabel('signal (V)')

ax = plt.subplot(1,3,2)
        
plt.plot(t,data)
plt.xlim([0,1])
plt.xlabel('time (s)')

ax = plt.subplot(1,3,3)        
plt.plot(t,data)
plt.xlim([0,0.1])
plt.xlabel('time (s)')


plt.show()
plt.close(fig)

# %%
freq_pow, power = scipy.signal.welch(data, axis = 0, fs = 1/resn,nperseg = 100000)

fig = plt.figure(figsize=(12, 3))

from detect_peaks import detect_peaks

peaks = detect_peaks(np.squeeze(power),mpd=3/(freq_pow[1]-freq_pow[0]))
peaks = peaks[np.argsort(np.squeeze(power[peaks]))][::-1]
peaks = peaks[0:10]

for freq,pow in zip(freq_pow[peaks], power[peaks]):
    print 'freq: %d, height: %.4f' % (freq, pow)
    
ax = plt.subplot(1,3,1)
plt.plot(freq_pow,power)
plt.xlim([0,5000])
plt.ylim([0,0.008])
plt.xlabel('freq (Hz)')
plt.ylabel('Noise power (V**2/Hz)')

ax = plt.subplot(1,3,2)
        
plt.plot(freq_pow,power)
plt.xlim([0,1000])
plt.ylim([0,0.008])
plt.xlabel('freq (Hz)')
plt.scatter(freq_pow[peaks],power[peaks],c='r')

ax = plt.subplot(1,3,3) 
plt.plot(freq_pow,power)
plt.xlim([0,10])
plt.ylim([0,0.8])
plt.xlabel('freq (Hz)')


plt.show()
plt.close(fig)
# Out:
# freq: 0, height: 1.3640
# freq: 121, height: 0.0061
# freq: 187, height: 0.0047
# freq: 374, height: 0.0030
# freq: 153, height: 0.0021
# freq: 115, height: 0.0019
# freq: 99, height: 0.0002
# freq: 728, height: 0.0002
# freq: 294, height: 0.0001
# freq: 445, height: 0.0001

# %%
min_freq = 100
max_freq = 1000

min_ind = np.argmin(np.abs(freq_pow-min_freq))
max_ind = np.argmin(np.abs(freq_pow-max_freq))

pow_int = scipy.integrate.trapz(power[min_ind:max_ind],freq_pow[min_ind:max_ind],axis=0)
full_pow = scipy.integrate.trapz(power,freq_pow,axis=0)

dc_freq = 3
dc_ind = np.argmin(np.abs(freq_pow-dc_freq))

pow_dc = scipy.integrate.trapz(power[0:dc_ind],freq_pow[0:dc_ind],axis=0)

rel_dc_pow = pow_dc/full_pow
print 'Relative DC power: %.3f' %rel_dc_pow

rel_pow = pow_int/full_pow
print 'Relative in-band power: %.3f' %rel_pow

rel_band_pow = pow_int/(full_pow-pow_dc)
print 'Relative in-band power (minus DC): %.3f' %rel_band_pow

print 'Full noise power: %.3e' %full_pow

print 'DC noise power: %.3e' %pow_dc
# Out:
# Relative DC power: 0.970
# Relative in-band power: 0.029
# Relative in-band power (minus DC): 0.972
# Full noise power: 3.389e-01
# DC noise power: 3.288e-01

# %%
freq_bin = 10.
min_freq = 3
max_freq = 1000

freq_rate = freq_pow[1]- freq_pow[0]
ind_bin = int(freq_bin/freq_rate)
min_ind = np.argmin(np.abs(freq_pow-min_freq))
max_ind = np.argmin(np.abs(freq_pow-max_freq))

cum_points = np.arange(min_ind,max_ind,ind_bin)

cum_freqs = freq_pow[cum_points[1:]]
cum_pow = np.zeros(np.shape(cum_freqs))

for x in range(len(cum_pow)-1):
    cum_pow[x+1] = cum_pow[x] + scipy.integrate.trapz(power[cum_points[x]:cum_points[x+1]],freq_pow[cum_points[x]:cum_points[x+1]],axis=0)

cum_pow = cum_pow/(full_pow-pow_dc)

fig = plt.figure()
ax = plt.subplot() 
plt.plot(cum_freqs,cum_pow)
plt.xlabel('freq (Hz)')
plt.ylabel('Integrated noise power (V**2)')

plt.show()
plt.close(fig)

# %% [markdown]
# ### Just to check, lets do a FFT

# %%
### fast fourier transform
from scipy.fftpack import fft

fft = fft(data,axis=0)
freq = np.fft.fftfreq(t.shape[-1],resn)

N = len(fft)
fft = fft[0:N/2]
freq = freq[0:N/2]

fig = plt.figure()
ax = plt.subplot()
        
plt.plot(freq,np.abs(fft))
plt.xlim([0,1000])
plt.ylim([0,10000])
plt.show()
plt.close(fig)

# %% [markdown]
# ## LT3 (LT4 blocked)

# %%
file_name = "LT3.csv"

filename = os.path.join(data_dir,file_name)

file = open(filename)
for x in range(9):
        line = file.readline()
        if "HResolution" in line:
            TimeRes = float(line[-18:-1])
file.close()

subdiv = 10
data = pandas.read_csv(os.path.join(data_dir,filename),header=None,skiprows = 15)
data = data.drop([0,2],1)
data = data.rolling(window = 100).mean()
data = data.as_matrix()[100:-100:subdiv]

resn = TimeRes*subdiv
t = resn*np.arange(len(data))

# %%
fig = plt.figure(figsize=(12, 3))

ax = plt.subplot(1,3,1)
plt.plot(t,data)
plt.xlabel('time (s)')
plt.ylabel('signal (V)')

ax = plt.subplot(1,3,2)
        
plt.plot(t,data)
plt.xlim([0,1])
plt.xlabel('time (s)')

ax = plt.subplot(1,3,3)        
plt.plot(t,data)
plt.xlim([0,0.1])
plt.xlabel('time (s)')


plt.show()
plt.close(fig)

# %%
freq_pow, power = scipy.signal.welch(data, axis = 0, fs = 1/resn,nperseg = 100000)

fig = plt.figure(figsize=(12, 3))

ax = plt.subplot(1,3,1)
plt.plot(freq_pow,power)
plt.xlim([0,5000])
plt.ylim([0,5e-6])
plt.xlabel('freq (Hz)')
plt.ylabel('Noise power (V**2/Hz)')
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))

ax = plt.subplot(1,3,2)
        
plt.plot(freq_pow,power)
plt.xlim([0,200])
plt.ylim([0,5e-6])
plt.xlabel('freq (Hz)')
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))


peaks = detect_peaks(np.squeeze(power),mpd=3/(freq_pow[1]-freq_pow[0]))
peaks = peaks[np.argsort(np.squeeze(power[peaks]))][::-1]
peaks = peaks[0:10]

for freq,pow in zip(freq_pow[peaks], power[peaks]):
    print 'freq: %d, height: %.2e' % (freq, pow)
    
plt.scatter(freq_pow[peaks],power[peaks],c='r')

ax = plt.subplot(1,3,3) 
plt.plot(freq_pow,power)
plt.xlim([0,10])
plt.ylim([0,5e-6])
plt.xlabel('freq (Hz)')
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))


plt.show()
plt.close(fig)
# Out:
# freq: 121, height: 4.52e-06
# freq: 0, height: 2.46e-06
# freq: 188, height: 2.47e-07
# freq: 80, height: 9.87e-08
# freq: 48, height: 3.98e-08
# freq: 4, height: 3.81e-08
# freq: 150, height: 3.45e-08
# freq: 154, height: 1.49e-08
# freq: 97, height: 1.29e-08
# freq: 117, height: 1.24e-08

# %%
min_freq = 10
max_freq = 1000

min_ind = np.argmin(np.abs(freq_pow-min_freq))
max_ind = np.argmin(np.abs(freq_pow-max_freq))

pow_int = scipy.integrate.trapz(power[min_ind:max_ind],freq_pow[min_ind:max_ind],axis=0)
full_pow = scipy.integrate.trapz(power,freq_pow,axis=0)

dc_freq = 10
dc_ind = np.argmin(np.abs(freq_pow-dc_freq))

pow_dc = scipy.integrate.trapz(power[0:dc_ind],freq_pow[0:dc_ind],axis=0)

rel_dc_pow = pow_dc/full_pow
print 'Relative DC power: %.3f' %rel_dc_pow

rel_pow = pow_int/full_pow
print 'Relative in-band power: %.3f' %rel_pow

rel_band_pow = pow_int/(full_pow-pow_dc)
print 'Relative in-band power (minus DC): %.3f' %rel_band_pow

print 'Full noise power: %.3e' %full_pow

print 'DC noise power: %.3e' %pow_dc
# Out:
# Relative DC power: 0.471
# Relative in-band power: 0.524
# Relative in-band power (minus DC): 0.991
# Full noise power: 2.445e-06
# DC noise power: 1.152e-06

# %%
freq_bin = 10.
min_freq = 3
max_freq = 1000

freq_rate = freq_pow[1]- freq_pow[0]
ind_bin = int(freq_bin/freq_rate)
min_ind = np.argmin(np.abs(freq_pow-min_freq))
max_ind = np.argmin(np.abs(freq_pow-max_freq))

cum_points = np.arange(min_ind,max_ind,ind_bin)

cum_freqs = freq_pow[cum_points[1:]]
cum_pow = np.zeros(np.shape(cum_freqs))

for x in range(len(cum_pow)-1):
    cum_pow[x+1] = cum_pow[x] + scipy.integrate.trapz(power[cum_points[x]:cum_points[x+1]],freq_pow[cum_points[x]:cum_points[x+1]],axis=0)

cum_pow = cum_pow/(full_pow-pow_dc)

fig = plt.figure()
ax = plt.subplot() 
plt.plot(cum_freqs,cum_pow)
plt.xlabel('freq (Hz)')
plt.ylabel('Integrated noise power (V**2)')

plt.show()
plt.close(fig)

# %% [markdown]
# ## LT4 (LT3 blocked)

# %%
file_name = "LT4.csv"

filename = os.path.join(data_dir,file_name)

file = open(filename)
for x in range(9):
        line = file.readline()
        if "HResolution" in line:
            TimeRes = float(line[-18:-1])
file.close()

subdiv = 10
data = pandas.read_csv(os.path.join(data_dir,filename),header=None,skiprows = 15)
data = data.drop([0,2],1)
data = data.rolling(window = 100).mean()
data = data.as_matrix()[100:-100:subdiv]

resn = TimeRes*subdiv
t = resn*np.arange(len(data))

# %%
fig = plt.figure(figsize=(12, 3))

ax = plt.subplot(1,3,1)
plt.plot(t,data)
plt.xlabel('time (s)')
plt.ylabel('signal (V)')

ax = plt.subplot(1,3,2)
        
plt.plot(t,data)
plt.xlim([0,1])
plt.xlabel('time (s)')

ax = plt.subplot(1,3,3)        
plt.plot(t,data)
plt.xlim([0,0.1])
plt.xlabel('time (s)')


plt.show()
plt.close(fig)

# %%
freq_pow, power = scipy.signal.welch(data, axis = 0, fs = 1/resn,nperseg = 100000)

fig = plt.figure(figsize=(12, 3))

ax = plt.subplot(1,3,1)
plt.plot(freq_pow,power)
plt.xlim([0,2000])
plt.ylim([0,20e-6])
plt.xlabel('freq (Hz)')
plt.ylabel('Noise power (V**2/Hz)')
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))

ax = plt.subplot(1,3,2)
        
plt.plot(freq_pow,power)
plt.xlim([0,300])
plt.ylim([0,20e-6])
plt.xlabel('freq (Hz)')
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))


peaks = detect_peaks(np.squeeze(power),mpd=3/(freq_pow[1]-freq_pow[0]))
peaks = peaks[np.argsort(np.squeeze(power[peaks]))][::-1]
peaks = peaks[0:10]

for freq,pow in zip(freq_pow[peaks], power[peaks]):
    print 'freq: %d, height: %.2e' % (freq, pow)
    
plt.scatter(freq_pow[peaks],power[peaks],c='r')


ax = plt.subplot(1,3,3) 
plt.plot(freq_pow,power)
plt.xlim([0,10])
plt.ylim([0,20e-6])
plt.xlabel('freq (Hz)')
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))


plt.show()
plt.close(fig)
# Out:
# freq: 115, height: 1.69e-05
# freq: 0, height: 3.99e-06
# freq: 231, height: 1.53e-07
# freq: 187, height: 1.46e-07
# freq: 149, height: 1.32e-07
# freq: 50, height: 9.84e-08
# freq: 95, height: 8.11e-08
# freq: 249, height: 7.20e-08
# freq: 4, height: 6.04e-08
# freq: 100, height: 3.51e-08

# %%
min_freq = 10
max_freq = 1000

min_ind = np.argmin(np.abs(freq_pow-min_freq))
max_ind = np.argmin(np.abs(freq_pow-max_freq))

pow_int = scipy.integrate.trapz(power[min_ind:max_ind],freq_pow[min_ind:max_ind],axis=0)
full_pow = scipy.integrate.trapz(power,freq_pow,axis=0)

dc_freq = 10
dc_ind = np.argmin(np.abs(freq_pow-dc_freq))

pow_dc = scipy.integrate.trapz(power[0:dc_ind],freq_pow[0:dc_ind],axis=0)

rel_dc_pow = pow_dc/full_pow
print 'Relative DC power: %.3f' %rel_dc_pow

rel_pow = pow_int/full_pow
print 'Relative in-band power: %.3f' %rel_pow

rel_band_pow = pow_int/(full_pow-pow_dc)
print 'Relative in-band power (minus DC): %.3f' %rel_band_pow

print 'Full noise power: %.3e' %full_pow

print 'DC noise power: %.3e' %pow_dc
# Out:
# Relative DC power: 0.375
# Relative in-band power: 0.623
# Relative in-band power (minus DC): 0.997
# Full noise power: 6.512e-06
# DC noise power: 2.440e-06

# %%
freq_bin = 5.
min_freq = 3
max_freq = 1000

freq_rate = freq_pow[1]- freq_pow[0]
ind_bin = int(freq_bin/freq_rate)
min_ind = np.argmin(np.abs(freq_pow-min_freq))
max_ind = np.argmin(np.abs(freq_pow-max_freq))

cum_points = np.arange(min_ind,max_ind,ind_bin)

cum_freqs = freq_pow[cum_points[1:]]
cum_pow = np.zeros(np.shape(cum_freqs))

for x in range(len(cum_pow)-1):
    cum_pow[x+1] = cum_pow[x] + scipy.integrate.trapz(power[cum_points[x]:cum_points[x+1]],freq_pow[cum_points[x]:cum_points[x+1]],axis=0)

cum_pow = cum_pow/(full_pow-pow_dc)

fig = plt.figure()
ax = plt.subplot() 
plt.plot(cum_freqs,cum_pow)
plt.xlabel('freq (Hz)')
plt.ylabel('Integrated noise power (V**2)')

plt.show()
plt.close(fig)
